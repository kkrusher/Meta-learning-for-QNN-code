# %%
import json5
import matplotlib.pyplot as plt
from pathlib import Path
from global_variable import exp_name
from plot_utils import plot_losses
# Out:
# Loaded Experiment Name: QAOA_qubits4_layers10_hamiltonianIsing_tfFalse

# %%
loss_path = f"./results/{exp_name}/gae_losses.json"
plot_losses(loss_path)

# %%
loss_path = f"./results/{exp_name}/hypernet_losses.json"
plot_losses(loss_path)
